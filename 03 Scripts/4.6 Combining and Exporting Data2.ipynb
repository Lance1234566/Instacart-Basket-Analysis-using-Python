# %% [markdown]
# ### Task 03. In a new notebook, import the orders_products_combined dataframe from the pickle file you just saved

# %%
# Import libraries 
import pandas as pd
import numpy as np
import os

# %%
# Set path
path = r'C:\Users\lance\Documents\Achievement 4 Project'

# %%
# Import and define dataframe ('orders_products_combined.pkl')
df_ords_prods = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))
df_prods_orig = pd.read_csv(os.path.join(path, '02 Data','Prepared Data', 'products_rechecked.csv'))

# %% [markdown]
# ### Task 04. Check the shape of the imported dataframes

# %%
# Check shape
df_ords_prods.shape
# Out:
# (32434489, 11)

# %% [markdown]
# ### Task 05. Determine a suitable way to combine the orders_products_combined dataframe with your products data set

# %%
# Check shape 
df_prods_orig.shape
# Out:
# (49670, 6)

# %%
# Identify shared column(s)
df_ords_prods.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  first_order  product_id  add_to_cart_order  \
# 0                     NaN         True         196                  1
# 1                     NaN         True       14084                  2
# 2                     NaN         True       12427                  3
# 3                     NaN         True       26088                  4
# 4                     NaN         True       26405                  5
#
#    reordered _merge
# 0          0   both
# 1          0   both
# 2          0   both
# ...

# %%
df_ords_prods.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  first_order  product_id  add_to_cart_order  \
# 0                     NaN         True         196                  1
# 1                     NaN         True       14084                  2
# 2                     NaN         True       12427                  3
# 3                     NaN         True       26088                  4
# 4                     NaN         True       26405                  5
#
#    reordered
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
df_prods_orig.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
# We can see that the 'product_id' column is the shared column between the two dataframes

# %%
# Now we can perform a merge between the two columns using the 'product_id' column as the common identifier
df_ords_prods_merged = df_ords_prods.merge(df_prods_orig, on = 'product_id', indicator = True)

# %%
df_ords_prods_merged.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  first_order  product_id  add_to_cart_order  \
# 0                     NaN         True         196                  1
# 1                    15.0        False         196                  1
# 2                    21.0        False         196                  1
# 3                    29.0        False         196                  1
# 4                    28.0        False         196                  1
#
#    reordered product_name  aisle_id  department_id  prices _merge
# ...

# %%
# Check the shape of the newly merged dataframe
df_ords_prods_merged.shape
# Out:
# (32399732, 15)

# %% [markdown]
# ### Task 06. Confirm the results of the merge using the merge flag

# %%
# Confirm the results of the merge by conducting a frequency check for the merge flags
df_ords_prods_merged['_merge'].value_counts()
# Out:
# _merge
# both          32399732
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
# The row counts of the merged dataframe matches the merge flagged rows because we use the default inner join

# %%
# We know these frequency counts to be misleading because we're only shown counts for 'both'
# An outer join must be performed to double check the merge rate
df_ords_prods_merged_check = df_ords_prods.merge(df_prods_orig, on='product_id', how='outer', indicator=True)

# %%
df_ords_prods_merged_check.head()
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0  2539329.0      1.0           1.0                 2.0                8.0
# 1  2398795.0      1.0           2.0                 3.0                7.0
# 2   473747.0      1.0           3.0                 3.0               12.0
# 3  2254736.0      1.0           4.0                 4.0                7.0
# 4   431534.0      1.0           5.0                 4.0               15.0
#
#    days_since_prior_order first_order  product_id  add_to_cart_order  \
# 0                     NaN        True         196                1.0
# 1                    15.0       False         196                1.0
# 2                    21.0       False         196                1.0
# 3                    29.0       False         196                1.0
# 4                    28.0       False         196                1.0
#
#    reordered product_name  aisle_id  department_id  prices _merge
# ...

# %%
df_ords_prods_merged_check['_merge'].value_counts()
# Out:
# _merge
# both          32399732
# left_only        35327
# right_only          11
# Name: count, dtype: int64

# %%
# These results show us the rows that have potentially mismatched keys, incomplete data, or different key columns
# However, in the previous exercise we opted to remove two outliers that may be responsible for these mismatches
# We must now investigate the cause of these mismatches

# %%
# Create a subset of the merged dataframe that only includes the 'left_only' rows
df_left_only = df_ords_prods_merged_check[df_ords_prods_merged_check['_merge'] == 'left_only']

# %%
# Inspect the results
df_left_only
# Out:
#            order_id   user_id  order_number  orders_day_of_week  \
# 10030345   912404.0      17.0          12.0                 2.0
# 10030346   603376.0      17.0          22.0                 6.0
# 10030347  3264360.0     135.0           2.0                 2.0
# 10030348   892534.0     135.0           3.0                 0.0
# 10030349   229704.0     342.0           8.0                 1.0
# ...             ...       ...           ...                 ...
# 32413293  1514902.0  179816.0           4.0                 5.0
# 32413294  3287190.0  179816.0           5.0                 6.0
# 32413295  2943026.0  179816.0           8.0                 0.0
# 32413296  2108832.0  179816.0          15.0                 2.0
# 32413297  1077336.0  202849.0          52.0                 1.0
#
#           order_hour_of_day  days_since_prior_order first_order  product_id  \
# 10030345               14.0                     5.0       False       21553
# ...

# %%
# It seems like there may be a lot of missing information
# When the outliers were remove the data set, only 2 rows of information was removed, so it's unlikely that's the cause
# We can check the product_id column for counts to ensure the outliers didn't affect anything
df_product_id_counts = df_left_only['product_id'].value_counts()
print(product_id_counts)
# Out:
# product_id
# 1511     13397
# 34        6536
# 21553     4429
# 116       4359
# 6799      1978
# 4790      1804
# 2240      1689
# 33664      698
# 262        179
# 3230        55
# 26519       51
# 1780        39
# 2586        29
# 69          19
# 525         18
# 4283        17
# 40440       13
# 3736         8
# 3159         5
# 38183        4
# Name: count, dtype: int64

# %%
# The product id's for the outliers were 21553 and 33664, however, there's many more product id's missing information

# %% [markdown]
# ### Task 07. Export the newly created dataframe as ords_prods_merged in a suitable format

# %%
# Considering the size of the newly created dataframe, it would be best to export it as a .pkl (pickle) file

# %%
df_ords_prods_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_combined_merged.pkl'))
